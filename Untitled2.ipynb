# %%
library(Seurat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bee256c6975b> in <module>()
# ----> 1 library(Seurat)
#
# NameError: name 'library' is not defined
